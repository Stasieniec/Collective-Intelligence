# %%
import energy_study_yes
import matplotlib.pyplot as plt
energy_list = energy_study_yes.run_simulation(20, 3, 10_000)

# Assuming list_for_plotting is structured as [(fox_population, rabbit_population)]
# Extracting fox and rabbit populations
rabbit_populations, fox_populations = zip(*energy_list)

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(fox_populations, label='Fox Population')
plt.plot(rabbit_populations, label='Rabbit Population')
plt.title('Population Dynamics')
plt.xlabel('Time Steps')
plt.ylabel('Population')
plt.legend()
plt.show()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.10.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Fox ID 20 ate: +5HP, health:14
# Rabbit died by fox, health 0
# Fox ID 20 ate: +5HP, health:19
# Rabbit died by fox, health 0
# Fox ID 21 ate: +5HP, health:13
# Rabbit died by fox, health 0
# Fox ID 20 ate: +5HP, health:23
# Rabbit died by fox, health 0
# Fox ID 26 ate: +5HP, health:14
# Rabbit died by fox, health 0
# Fox ID 26 ate: +5HP, health:19
# Rabbit died by fox, health 0
# Fox ID 31 ate: +5HP, health:15
# Rabbit died by fox, health 0
# Fox ID 26 ate: +5HP, health:24
# Rabbit died by fox, health 0
# Fox ID 27 ate: +5HP, health:11
# Rabbit died by fox, health 0
# Fox ID 22 ate: +5HP, health:9
# Rabbit died by fox, health 0
# Fox ID 39 ate: +5HP, health:15
# Rabbit died by fox, health 0
# Fox ID 27 ate: +5HP, health:15
# Rabbit died by fox, health 0
# Fox ID 39 ate: +5HP, health:19
# Rabbit died by fox, health 0
# Fox ID 31 ate: +5HP, health:14
# ...

# %%
import energy_study_no
import matplotlib.pyplot as plt
no_energy_list = energy_study_no.run_simulation(20, 3, 10_000)

# Assuming list_for_plotting is structured as [(fox_population, rabbit_population)]
# Extracting fox and rabbit populations
rabbit_populations, fox_populations = zip(*no_energy_list)

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(fox_populations, label='Fox Population')
plt.plot(rabbit_populations, label='Rabbit Population')
plt.title('Population Dynamics')
plt.xlabel('Time Steps')
plt.ylabel('Population')
plt.legend()
plt.show()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.10.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Fox ID 20 ate: +5HP, health:15
# Rabbit died by fox, health 0
# Fox ID 20 ate: +5HP, health:20
# Rabbit died by fox, health 0
# Fox ID 22 ate: +5HP, health:15
# Rabbit died by fox, health 0
# Fox ID 22 ate: +5HP, health:20
# Rabbit died by fox, health 0
# Fox ID 27 ate: +5HP, health:15
# Rabbit died by fox, health 0
# Fox probabilistically died
# Fox ID 24 died of starvation, silly fox
# Fox probabilistically died
# Fox ID 29 died of starvation, silly fox
# Fox probabilistically died
# Fox ID 21 died of starvation, silly fox
# Fox probabilistically died
# Fox ID 20 died of starvation, silly fox
# Fox ID 28 ate: +5HP, health:15
# Rabbit died by fox, health 0
# Fox ID 28 ate: +5HP, health:20
# Rabbit died by fox, health 0
# Fox ID 43 ate: +5HP, health:15
# Rabbit died by fox, health 0
# Fox ID 43 ate: +5HP, health:20
# Rabbit died by fox, health 0
# ...

# %%
import matplotlib.pyplot as plt
import energy_study_no
import energy_study_yes

# Assuming you have already run the simulations and extracted the populations
# For energy_study_yes
energy_list = energy_study_yes.run_simulation(20, 3, 20_000)
rabbit_populations_yes, fox_populations_yes = zip(*energy_list)

# For energy_study_no
no_energy_list = energy_study_no.run_simulation(20, 3, 20_000)
rabbit_populations_no, fox_populations_no = zip(*no_energy_list)

# Plotting both on the same figure
plt.figure(figsize=(10, 5))
plt.plot(fox_populations_yes, label='Fox Population (Energy)', color='blue')
plt.plot(rabbit_populations_yes, label='Rabbit Population (Energy)', color='cyan')
plt.plot(fox_populations_no, label='Fox Population (No Energy)', color='red')
plt.plot(rabbit_populations_no, label='Rabbit Population (No Energy)', color='orange')
plt.title('Population Dynamics with and without Energy Considerations')
plt.xlabel('Time Steps')
plt.ylabel('Population')
plt.legend()
plt.show()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.10.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Fox ID 20 ate: +5HP, health:14
# Rabbit died by fox, health 0
# Fox ID 20 ate: +5HP, health:19
# Rabbit died by fox, health 0
# Fox ID 21 ate: +5HP, health:13
# Rabbit died by fox, health 0
# Fox ID 20 ate: +5HP, health:23
# Rabbit died by fox, health 0
# Fox ID 26 ate: +5HP, health:14
# Rabbit died by fox, health 0
# Fox ID 26 ate: +5HP, health:19
# Rabbit died by fox, health 0
# Fox ID 31 ate: +5HP, health:15
# Rabbit died by fox, health 0
# Fox ID 26 ate: +5HP, health:24
# Rabbit died by fox, health 0
# Fox ID 27 ate: +5HP, health:11
# Rabbit died by fox, health 0
# Fox ID 22 ate: +5HP, health:9
# Rabbit died by fox, health 0
# Fox ID 39 ate: +5HP, health:15
# Rabbit died by fox, health 0
# Fox ID 27 ate: +5HP, health:15
# Rabbit died by fox, health 0
# Fox ID 39 ate: +5HP, health:19
# Rabbit died by fox, health 0
# Fox ID 31 ate: +5HP, health:14
# ...
