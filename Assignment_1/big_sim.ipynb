# %%
import new_speed_different as sim_dif
import new_speed_symmetry as sim_sym
import speed_bonus_experiment as sim_bonus

# %%
for i in range(1, 100):
    for j in range(0, 10):
        sim_dif.run_simulation(i)
    print(f'{i} simulations done')
# Out:
# 1 simulations done
# 2 simulations done
# 3 simulations done
# 4 simulations done
# 5 simulations done
# 6 simulations done
# 7 simulations done
# 8 simulations done
# 9 simulations done
# 10 simulations done
# 11 simulations done
# 12 simulations done
# 13 simulations done
# 14 simulations done
# 15 simulations done
# 16 simulations done
# 17 simulations done
# 18 simulations done
# 19 simulations done
# 20 simulations done
# 21 simulations done
# 22 simulations done
# 23 simulations done
# 24 simulations done
# 25 simulations done
# 26 simulations done
# 27 simulations done
# 28 simulations done
# 29 simulations done
# 30 simulations done
# 31 simulations done
# 32 simulations done
# 33 simulations done
# 34 simulations done
# 35 simulations done
# 36 simulations done
# 37 simulations done
# 38 simulations done
# 39 simulations done
# 40 simulations done
# 41 simulations done
# 42 simulations done
# 43 simulations done
# 44 simulations done
# 45 simulations done
# 46 simulations done
# 47 simulations done
# 48 simulations done
# 49 simulations done
# 50 simulations done
# 51 simulations done
# 52 simulations done
# 53 simulations done
# 54 simulations done
# 55 simulations done
# 56 simulations done
# 57 simulations done
# 58 simulations done
# 59 simulations done
# 60 simulations done
# 61 simulations done
# 62 simulations done
# 63 simulations done
# 64 simulations done
# 65 simulations done
# 66 simulations done
# 67 simulations done
# 68 simulations done
# 69 simulations done
# 70 simulations done
# 71 simulations done
# 72 simulations done
# 73 simulations done
# 74 simulations done
# 75 simulations done
# 76 simulations done
# 77 simulations done
# 78 simulations done
# 79 simulations done
# 80 simulations done
# 81 simulations done
# 82 simulations done
# 83 simulations done
# 84 simulations done
# 85 simulations done
# 86 simulations done
# 87 simulations done
# 88 simulations done
# 89 simulations done
# 90 simulations done
# 91 simulations done
# 92 simulations done
# 93 simulations done
# 94 simulations done
# 95 simulations done
# 96 simulations done
# 97 simulations done
# 98 simulations done
# 99 simulations done

# %%
for i in range(1, 100):
    for j in range(0, 10):
        sim_sym.run_simulation(i)
    print(f'{i} simulations done')
# Out:
# 1 simulations done
# 2 simulations done
# 3 simulations done
# 4 simulations done
# 5 simulations done
# 6 simulations done
# 7 simulations done
# 8 simulations done
# 9 simulations done
# 10 simulations done
# 11 simulations done
# 12 simulations done
# 13 simulations done
# 14 simulations done
# 15 simulations done
# 16 simulations done
# 17 simulations done
# 18 simulations done
# 19 simulations done
# 20 simulations done
# 21 simulations done
# 22 simulations done
# 23 simulations done
# 24 simulations done
# 25 simulations done
# 26 simulations done
# 27 simulations done
# 28 simulations done
# 29 simulations done
# 30 simulations done
# 31 simulations done
# 32 simulations done
# 33 simulations done
# 34 simulations done
# 35 simulations done
# 36 simulations done
# 37 simulations done
# 38 simulations done
# 39 simulations done
# 40 simulations done
# 41 simulations done
# 42 simulations done
# 43 simulations done
# 44 simulations done
# 45 simulations done
# 46 simulations done
# 47 simulations done
# 48 simulations done
# 49 simulations done
# 50 simulations done
# 51 simulations done
# 52 simulations done
# 53 simulations done
# 54 simulations done
# 55 simulations done
# 56 simulations done
# 57 simulations done
# 58 simulations done
# 59 simulations done
# 60 simulations done
# 61 simulations done
# 62 simulations done
# 63 simulations done
# 64 simulations done
# 65 simulations done
# 66 simulations done
# 67 simulations done
# 68 simulations done
# 69 simulations done
# 70 simulations done
# 71 simulations done
# 72 simulations done
# 73 simulations done
# 74 simulations done
# 75 simulations done
# 76 simulations done
# 77 simulations done
# 78 simulations done
# 79 simulations done
# 80 simulations done
# 81 simulations done
# 82 simulations done
# 83 simulations done
# 84 simulations done
# 85 simulations done
# 86 simulations done
# 87 simulations done
# 88 simulations done
# 89 simulations done
# 90 simulations done
# 91 simulations done
# 92 simulations done
# 93 simulations done
# 94 simulations done
# 95 simulations done
# 96 simulations done
# 97 simulations done
# 98 simulations done
# 99 simulations done
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
for i_ in range(0, 98, 2):
    i = 98 - i_
    sim_bonus.run_simulation(i)
    print(f'{i_} simulations done')
# Out:
# 0 simulations done
# 2 simulations done
# 4 simulations done
# 6 simulations done
# 8 simulations done
# 10 simulations done
# 12 simulations done
# 14 simulations done
# 16 simulations done
# 18 simulations done
# 20 simulations done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 for i_ in range(0, 98, 2):
#       2     i = 98 - i_
# ----> 3     sim_bonus.run_simulation(i)
#       4     print(f'{i_} simulations done')
#
# File c:\UNIVERSITY\2nd year\CollectiveIntelligence\Collective-Intelligence\speed_bonus_experiment.py:224, in run_simulation(number_of_roaches)
#     215 def run_simulation(number_of_roaches):
#     216     AggregationSimulation(
#     217         AggregationConfig(
#     218             fps_limit=0,
#     219             seed=1.5,
#     220             movement_speed=25,
#     221             radius=50,
#     222             image_rotation=True,
#     223         ), number_of_roaches
# --> 224     ).batch_spawn_agents(number_of_roaches, Cockroach, images=["Assignment_0/images/roach40.png"]).run()
#
# File c:\Users\wasil\anaconda3\envs\ml01\lib\site-packages\vi\simulation.py:311, in HeadlessSimulation.run(self)
#     308 self._running = True
#     310 while self._running:
# --> 311     self.tick()
#     313 return self._metrics
#
# File c:\Users\wasil\anaconda3\envs\ml01\lib\site-packages\vi\simulation.py:353, in HeadlessSimulation.tick(self)
#     350 # Merge the collected snapshots into the dataframe.
#     351 self._metrics._merge()
# --> 353 self.after_update()
#     355 # If we've reached the duration of the simulation, then stop the simulation.
#     356 if self.config.duration > 0 and self.shared.counter == self.config.duration:
#
# File c:\Users\wasil\anaconda3\envs\ml01\lib\site-packages\vi\simulation.py:466, in Simulation.after_update(self)
#     464 def after_update(self):
#     465     # Draw everything to the screen
# --> 466     self._all.draw(self._screen)
#     468     if self.config.visualise_chunks:
#     469         self.__visualise_chunks()
#
# File c:\Users\wasil\anaconda3\envs\ml01\lib\site-packages\pygame\sprite.py:572, in AbstractGroup.draw(self, surface, bgsurf, special_flags)
#     567 sprites = self.sprites()
#     568 if hasattr(surface, "blits"):
#     569     self.spritedict.update(
#     570         zip(
#     571             sprites,
# --> 572             surface.blits(
#     573                 (spr.image, spr.rect, None, special_flags) for spr in sprites
#     574             ),
#     575         )
#     576     )
#     577 else:
#     578     for spr in sprites:
#
# File c:\Users\wasil\anaconda3\envs\ml01\lib\site-packages\pygame\sprite.py:573, in <genexpr>(.0)
#     567 sprites = self.sprites()
#     568 if hasattr(surface, "blits"):
#     569     self.spritedict.update(
#     570         zip(
#     571             sprites,
#     572             surface.blits(
# --> 573                 (spr.image, spr.rect, None, special_flags) for spr in sprites
#     574             ),
#     575         )
#     576     )
#     577 else:
#     578     for spr in sprites:
#
# File c:\Users\wasil\anaconda3\envs\ml01\lib\site-packages\vi\agent.py:171, in Agent.image(self)
#     168     if frame == self.shared.counter:
#     169         return image
# --> 171 new_image = self._get_image()
#     172 self._image_cache = (self.shared.counter, new_image)
#     174 return new_image
#
# File c:\Users\wasil\anaconda3\envs\ml01\lib\site-packages\vi\agent.py:158, in Agent._get_image(self)
#     155 if self.config.image_rotation:
#     156     angle = self.move.angle_to(Vector2((0, -1)))
# --> 158     return pg.transform.rotate(image, angle)
#     159 else:
#     160     return image
#
# KeyboardInterrupt:
